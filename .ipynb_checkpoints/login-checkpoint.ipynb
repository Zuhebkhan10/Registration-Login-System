# %%
# Import the tkinter package
import tkinter as tk
from tkinter import messagebox

# Setup the window
root=tk.Tk()
root.title("Registration Login System")
root.geometry("600x400")
root.config(bg="#f0f2f5")

# %%
# Create the center card frame
card=tk.Frame(root,bg="white",width=350,height=320)
card.place(relx=0.5,rely=0.5,anchor="center")

# Create the title
title=tk.Label(card,text="Login",font=("Segoe UI",22,"bold"),bg="white")
title.pack(pady=20)

#Create the username
user_label=tk.Label(card,text="username",bg="white",font=("Segoe UI",10))
user_label.pack()

user_entry=tk.Entry(card,width=50,font=("Segoe UI",11),bd=1)
user_entry.pack(pady=5)

# %%
# Create the password
password_label=tk.Label(card,text="Password",bg-"WHITE",font=("Segoe UI ",10))
password_label.pack()

password_entry=tk.Entry(card,"*",width=30,font=("Segoe UI",11),bd=1)
password.entry.pack(pady=5)
# Out:
#   Cell In[23], line 2
#     password_label=tk.Label(card,text="Password",bg-"WHITE",font=("Segoe UI ",10))
#                                                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
# Create the Login function
def login():
    username=user_entry.get()
    password=password_entry.get()

    try:
        with open(users.txt,"r")as f:
            user=f.readlines()

    except:
        meassgae.showererror("Error ?","No user registered")
        return

    for user in users:
        u,p=user.strip().split(":")

        if username==u and password==p:
            message.showinfo("Success","Login Successful")
            return
    meassagebox.showerror("Error","Invalid Email")

# %%
# Create the registor function
username=user_entry.get()
password=password_entry.get()

with open("users.txt","a")as f:
    f.write(username+":"+password + "\n")
messagebox.showinfo("Success","Account created")
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[39], line 3
#       1 # Create the registor function
#       2 username=user_entry.get()
# ----> 3 password=password_entry.get()
#       5 with open("users.txt","a")as f:
#       6     f.write(username+":"+password + "\n")
#
# File ~\anaconda3\Lib\tkinter\__init__.py:3262, in Entry.get(self)
#    3260 def get(self):
#    3261     """Return the text."""
# -> 3262     return self.tk.call(self._w, 'get')
#
# TclError: invalid command name ".!frame2.!entry2"
